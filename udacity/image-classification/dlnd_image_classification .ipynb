# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

# Use Floyd's cifar-10 dataset if present
floyd_cifar10_location = '/input/cifar-10/python.tar.gz'
if isfile(floyd_cifar10_location):
    tar_gz_path = floyd_cifar10_location
else:
    tar_gz_path = 'cifar-10-python.tar.gz'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(tar_gz_path):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            tar_gz_path,
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open(tar_gz_path) as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# CIFAR-10 Dataset: 171MB [00:22, 7.66MB/s]
# All files found!

# %% [markdown]
# ## Explore the Data
# The dataset is broken into batches to prevent your machine from running out of memory.  The CIFAR-10 dataset consists of 5 batches, named `data_batch_1`, `data_batch_2`, etc.. Each batch contains the labels and images that are one of the following:
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck
#
# Understanding a dataset is part of making predictions on the data.  Play around with the code cell below by changing the `batch_id` and `sample_id`. The `batch_id` is the id for a batch (1-5). The `sample_id` is the id for a image and label pair in the batch.
#
# Ask yourself "What are all possible labels?", "What is the range of values for the image data?", "Are the labels in order or random?".  Answers to questions like these will help you preprocess the data and end up with better predictions.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 1
sample_id = 4
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 1:
# Samples: 10000
# Label Counts: {0: 1005, 1: 974, 2: 1032, 3: 1016, 4: 999, 5: 937, 6: 1030, 7: 1001, 8: 1025, 9: 981}
# First 20 Labels: [6, 9, 9, 4, 1, 1, 2, 7, 8, 3, 4, 7, 7, 2, 9, 9, 9, 3, 2, 6]
#
# Example of Image 4:
# Image - Min Value: 0 Max Value: 254
# Image - Shape: (32, 32, 3)
# Label - Label Id: 1 Name: automobile

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %%
def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    # TODO: Implement Function
    a = 0
    b = 1
    grayscale_min = 0
    grayscale_max = 255
    
    return  a +  (x - grayscale_min + b-1) / (grayscale_max - grayscale_min)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# Tests Passed

# %% [markdown]
# ### One-hot encode
# Just like the previous code cell, you'll be implementing a function for preprocessing.  This time, you'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.
#
# Hint: Don't reinvent the wheel.

# %%
def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    # TODO: Implement Function
    onehots = []
    for each in x :
        zero= np.zeros(10)
        zero[each] =1
        onehots.append(zero)
    return np.array(onehots)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # Check Point
# This is your first checkpoint.  If you ever decide to come back to this notebook or have to restart the notebook, you can start from here.  The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## Build the network
# For the neural network, you'll build each layer into a function.  Most of the code you've seen has been outside of functions. To test your code more thoroughly, we require that you put each layer in a function.  This allows us to give you better feedback and test for simple mistakes using our unittests before you submit your project.
#
# >**Note:** If you're finding it hard to dedicate enough time for this course each week, we've provided a small shortcut to this part of the project. In the next couple of problems, you'll have the option to use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages to build each layer, except the layers you build in the "Convolutional and Max Pooling Layer" section.  TF Layers is similar to Keras's and TFLearn's abstraction to layers, so it's easy to pickup.
#
# >However, if you would like to get the most out of this course, try to solve all the problems _without_ using anything from the TF Layers packages. You **can** still use classes from other packages that happen to have the same name as ones you find in TF Layers! For example, instead of using the TF Layers version of the `conv2d` class, [tf.layers.conv2d](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d), you would want to use the TF Neural Network version of `conv2d`, [tf.nn.conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d).
#
# Let's begin!
#
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %%
import tensorflow as tf

def neural_net_image_input(image_shape):
    """
    Return a Tensor for a batch of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    # TODO: Implement Function
    return  tf.placeholder(tf.float32, shape=[None, image_shape[0],  image_shape[1],  image_shape[2]], name='x')


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32,shape=[None,n_classes],name='y')


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32,name='keep_prob')


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
#
# **Note:** You **can't** use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for **this** layer, but you can still use TensorFlow's [Neural Network](https://www.tensorflow.org/api_docs/python/tf/nn) package. You may still use the shortcut option for all the **other** layers.

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    # TODO: Implement Function
    # 卷积
        #设置卷积核参数
    print(x_tensor.get_shape())
    FilterW= tf.Variable(tf.truncated_normal((conv_ksize[0], conv_ksize[1], x_tensor.get_shape()[3].value, conv_num_outputs),stddev=0.05)) ## (height, width, input_depth, output_depth)
    strides = [1, conv_strides[0], conv_strides[1], 1]
    padding = 'SAME'
    bias = tf.random_normal([conv_num_outputs])
    conv = tf.nn.conv2d(x_tensor, FilterW, strides, padding)
    conv = tf.nn.bias_add(conv, bias)
    conv= tf.nn.relu(conv)
    #池化
    ksize = [1, pool_ksize[0], pool_ksize[1], 1]
    strides = [1, pool_strides[0], pool_strides[1], 1]
    padding = 'SAME'
    return tf.nn.max_pool(conv, ksize, strides, padding)
    


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# (?, 32, 32, 5)
# Tests Passed

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    return tf.reshape(x_tensor, [-1, x_tensor.shape[1].value * x_tensor.shape[2].value* x_tensor.shape[3].value])


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# Tests Passed

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    weight= tf.Variable(tf.truncated_normal([x_tensor.shape[1].value, num_outputs], mean=0.0, stddev=0.1))
    #bias =  tf.Variable(tf.random_normal([num_outputs]))
    bias = tf.Variable(tf.zeros(num_outputs))
    fc1 =tf.nn.bias_add(tf.matmul(x_tensor, weight), bias)
    fc1 = tf.nn.relu(fc1)
    
    return fc1


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# Tests Passed

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.
#
# **Note:** Activation, softmax, or cross entropy should **not** be applied to this.

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function

    weight= tf.Variable(tf.truncated_normal([x_tensor.shape[1].value, num_outputs], mean=0.0, stddev=0.01))
    #bias =  tf.Variable(tf.random_normal([num_outputs]))
    bias = tf.Variable(tf.zeros(num_outputs))
    
    return tf.nn.bias_add(tf.matmul(x_tensor, weight), bias)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Tests Passed

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    # TODO: Apply 1, 2, or 3 Convolution and Max Pool layers
    #    Play around with different number of outputs, kernel size and stride
    # Function Definition from Above:
    #    conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    conv1 = conv2d_maxpool(x, 64, [3,3], [2,2], [2,2], [2,2])
    conv2 = conv2d_maxpool(conv1, 128, [3,3], [2,2], [2,2], [2,2])
    conv3 = conv2d_maxpool(conv2, 256, [3,3], [2,2], [2,2], [2,2])
    
    

    # TODApply a Flatten Layer
    # Function Definition from Above:
    #   flatten(x_tensor)
    fl0 = flatten(conv3)

    # TODO: Apply a Flatten Layer
    # Function Definition from Above:
    fl1 = fully_conn(fl0, 100)
    fl1 = tf.nn.relu(fl1)
    fl1 = tf.nn.dropout(fl1, keep_prob)
    
    fl2 = fully_conn(fl1, 50)
    fl2= tf.nn.relu(fl2)
    fl2 = tf.nn.dropout(fl2, keep_prob)

    # TODO: Apply 1, 2, or 3 Fully Connected Layers
    #    Play around with different number of outputs
    # Function Definition from Above:
    #   fully_conn(x_tensor, num_outputs)
    
    
    # TODO: Apply an Output Layer
    #    Set this to the number of classes
    # Function Definition from Above:
    #   output(x_tensor, num_outputs)
    
    out = output(fl2,10)
    # TODO: return output
    return out


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# (?, 32, 32, 3)
# (?, 8, 8, 64)
# (?, 2, 2, 128)
# (?, 32, 32, 3)
# (?, 8, 8, 64)
# (?, 2, 2, 128)
# Neural Network Built!

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    # TODO: Implement Function
    session.run(optimizer,feed_dict={x:feature_batch, y:label_batch, keep_prob: keep_probability})

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    loss = session.run(cost, feed_dict={x:feature_batch, y: label_batch, keep_prob:1.0 })
    valid_acc =session.run(accuracy, feed_dict={x:valid_features, y: valid_labels, keep_prob:1.0})
    print('Loss: {:>10.4f}  Validation Accuracy: {:.6f}'.format(loss, valid_acc))

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
# TODO: Tune Parameters
epochs = 100
batch_size = 256
keep_probability = 0.5

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:  Loss:     2.3008  Validation Accuracy: 0.099800
# Epoch  2, CIFAR-10 Batch 1:  Loss:     2.3045  Validation Accuracy: 0.099800
# Epoch  3, CIFAR-10 Batch 1:  Loss:     2.2963  Validation Accuracy: 0.099800
# Epoch  4, CIFAR-10 Batch 1:  Loss:     2.3029  Validation Accuracy: 0.125600
# Epoch  5, CIFAR-10 Batch 1:  Loss:     2.3003  Validation Accuracy: 0.090400
# Epoch  6, CIFAR-10 Batch 1:  Loss:     2.3030  Validation Accuracy: 0.099800
# Epoch  7, CIFAR-10 Batch 1:  Loss:     2.3007  Validation Accuracy: 0.105000
# Epoch  8, CIFAR-10 Batch 1:  Loss:     2.3033  Validation Accuracy: 0.095400
# Epoch  9, CIFAR-10 Batch 1:  Loss:     2.3011  Validation Accuracy: 0.127400
# Epoch 10, CIFAR-10 Batch 1:  Loss:     2.2693  Validation Accuracy: 0.163800
# Epoch 11, CIFAR-10 Batch 1:  Loss:     2.5028  Validation Accuracy: 0.162400
# Epoch 12, CIFAR-10 Batch 1:  Loss:     2.2603  Validation Accuracy: 0.191800
# Epoch 13, CIFAR-10 Batch 1:  Loss:     2.2690  Validation Accuracy: 0.138000
# Epoch 14, CIFAR-10 Batch 1:  Loss:     2.2306  Validation Accuracy: 0.158600
# Epoch 15, CIFAR-10 Batch 1:  Loss:     2.2138  Validation Accuracy: 0.214000
# Epoch 16, CIFAR-10 Batch 1:  Loss:     2.2188  Validation Accuracy: 0.205800
# Epoch 17, CIFAR-10 Batch 1:  Loss:     2.2259  Validation Accuracy: 0.200600
# Epoch 18, CIFAR-10 Batch 1:  Loss:     2.2266  Validation Accuracy: 0.213600
# Epoch 19, CIFAR-10 Batch 1:  Loss:     2.2026  Validation Accuracy: 0.170800
# Epoch 20, CIFAR-10 Batch 1:  Loss:     2.1841  Validation Accuracy: 0.173400
# Epoch 21, CIFAR-10 Batch 1:  Loss:     2.2021  Validation Accuracy: 0.230000
# Epoch 22, CIFAR-10 Batch 1:  Loss:     2.1713  Validation Accuracy: 0.232400
# Epoch 23, CIFAR-10 Batch 1:  Loss:     2.1676  Validation Accuracy: 0.234000
# Epoch 24, CIFAR-10 Batch 1:  Loss:     2.2108  Validation Accuracy: 0.202000
# Epoch 25, CIFAR-10 Batch 1:  Loss:     2.1649  Validation Accuracy: 0.223200
# Epoch 26, CIFAR-10 Batch 1:  Loss:     2.1913  Validation Accuracy: 0.199800
# Epoch 27, CIFAR-10 Batch 1:  Loss:     2.1712  Validation Accuracy: 0.228000
# Epoch 28, CIFAR-10 Batch 1:  Loss:     2.1838  Validation Accuracy: 0.212800
# Epoch 29, CIFAR-10 Batch 1:  Loss:     2.1756  Validation Accuracy: 0.194000
# Epoch 30, CIFAR-10 Batch 1:  Loss:     2.2238  Validation Accuracy: 0.241000
# Epoch 31, CIFAR-10 Batch 1:  Loss:     2.2457  Validation Accuracy: 0.246400
# Epoch 32, CIFAR-10 Batch 1:  Loss:     2.1840  Validation Accuracy: 0.241200
# Epoch 33, CIFAR-10 Batch 1:  Loss:     2.1439  Validation Accuracy: 0.183400
# Epoch 34, CIFAR-10 Batch 1:  Loss:     2.1366  Validation Accuracy: 0.184400
# Epoch 35, CIFAR-10 Batch 1:  Loss:     2.1533  Validation Accuracy: 0.248600
# Epoch 36, CIFAR-10 Batch 1:  Loss:     2.1815  Validation Accuracy: 0.220600
# Epoch 37, CIFAR-10 Batch 1:  Loss:     2.1988  Validation Accuracy: 0.243800
# Epoch 38, CIFAR-10 Batch 1:  Loss:     2.1572  Validation Accuracy: 0.211000
# Epoch 39, CIFAR-10 Batch 1:  Loss:     2.1737  Validation Accuracy: 0.233200
# Epoch 40, CIFAR-10 Batch 1:  Loss:     2.1181  Validation Accuracy: 0.246000
# Epoch 41, CIFAR-10 Batch 1:  Loss:     2.2396  Validation Accuracy: 0.263400
# Epoch 42, CIFAR-10 Batch 1:  Loss:     2.1451  Validation Accuracy: 0.243800
# Epoch 43, CIFAR-10 Batch 1:  Loss:     2.1700  Validation Accuracy: 0.264800
# Epoch 44, CIFAR-10 Batch 1:  Loss:     2.0913  Validation Accuracy: 0.206400
# Epoch 45, CIFAR-10 Batch 1:  Loss:     2.1119  Validation Accuracy: 0.251800
# Epoch 46, CIFAR-10 Batch 1:  Loss:     2.1532  Validation Accuracy: 0.259600
# Epoch 47, CIFAR-10 Batch 1:  Loss:     2.0940  Validation Accuracy: 0.269000
# Epoch 48, CIFAR-10 Batch 1:  Loss:     2.1545  Validation Accuracy: 0.245000
# Epoch 49, CIFAR-10 Batch 1:  Loss:     2.0624  Validation Accuracy: 0.247600
# Epoch 50, CIFAR-10 Batch 1:  Loss:     2.0181  Validation Accuracy: 0.223600
# Epoch 51, CIFAR-10 Batch 1:  Loss:     2.0214  Validation Accuracy: 0.272000
# Epoch 52, CIFAR-10 Batch 1:  Loss:     2.0892  Validation Accuracy: 0.253600
# Epoch 53, CIFAR-10 Batch 1:  Loss:     2.0725  Validation Accuracy: 0.260200
# Epoch 54, CIFAR-10 Batch 1:  Loss:     2.0381  Validation Accuracy: 0.279800
# Epoch 55, CIFAR-10 Batch 1:  Loss:     2.0238  Validation Accuracy: 0.273800
# Epoch 56, CIFAR-10 Batch 1:  Loss:     2.0445  Validation Accuracy: 0.240600
# Epoch 57, CIFAR-10 Batch 1:  Loss:     1.9594  Validation Accuracy: 0.298600
# Epoch 58, CIFAR-10 Batch 1:  Loss:     2.1605  Validation Accuracy: 0.308600
# Epoch 59, CIFAR-10 Batch 1:  Loss:     2.0734  Validation Accuracy: 0.293000
# Epoch 60, CIFAR-10 Batch 1:  Loss:     1.9923  Validation Accuracy: 0.299600
# Epoch 61, CIFAR-10 Batch 1:  Loss:     1.9464  Validation Accuracy: 0.307800
# Epoch 62, CIFAR-10 Batch 1:  Loss:     1.9437  Validation Accuracy: 0.290400
# Epoch 63, CIFAR-10 Batch 1:  Loss:     1.9292  Validation Accuracy: 0.309400
# Epoch 64, CIFAR-10 Batch 1:  Loss:     1.9687  Validation Accuracy: 0.297200
# Epoch 65, CIFAR-10 Batch 1:  Loss:     2.0259  Validation Accuracy: 0.316000
# Epoch 66, CIFAR-10 Batch 1:  Loss:     1.9095  Validation Accuracy: 0.294200
# Epoch 67, CIFAR-10 Batch 1:  Loss:     1.9872  Validation Accuracy: 0.317600
# Epoch 68, CIFAR-10 Batch 1:  Loss:     2.0457  Validation Accuracy: 0.302600
# Epoch 69, CIFAR-10 Batch 1:  Loss:     1.9283  Validation Accuracy: 0.328600
# Epoch 70, CIFAR-10 Batch 1:  Loss:     2.0215  Validation Accuracy: 0.335800
# Epoch 71, CIFAR-10 Batch 1:  Loss:     1.9147  Validation Accuracy: 0.324200
# Epoch 72, CIFAR-10 Batch 1:  Loss:     1.9254  Validation Accuracy: 0.335600
# Epoch 73, CIFAR-10 Batch 1:  Loss:     1.8892  Validation Accuracy: 0.333000
# Epoch 74, CIFAR-10 Batch 1:  Loss:     1.8654  Validation Accuracy: 0.329000
# Epoch 75, CIFAR-10 Batch 1:  Loss:     1.8466  Validation Accuracy: 0.349800
# Epoch 76, CIFAR-10 Batch 1:  Loss:     1.9201  Validation Accuracy: 0.321400
# Epoch 77, CIFAR-10 Batch 1:  Loss:     1.9311  Validation Accuracy: 0.350200
# Epoch 78, CIFAR-10 Batch 1:  Loss:     2.0606  Validation Accuracy: 0.335200
# Epoch 79, CIFAR-10 Batch 1:  Loss:     1.9767  Validation Accuracy: 0.351400
# Epoch 80, CIFAR-10 Batch 1:  Loss:     1.9597  Validation Accuracy: 0.367000
# Epoch 81, CIFAR-10 Batch 1:  Loss:     1.7476  Validation Accuracy: 0.318400
# Epoch 82, CIFAR-10 Batch 1:  Loss:     1.9480  Validation Accuracy: 0.360800
# Epoch 83, CIFAR-10 Batch 1:  Loss:     1.8073  Validation Accuracy: 0.336600
# Epoch 84, CIFAR-10 Batch 1:  Loss:     1.7650  Validation Accuracy: 0.342400
# Epoch 85, CIFAR-10 Batch 1:  Loss:     2.1041  Validation Accuracy: 0.327200
# Epoch 86, CIFAR-10 Batch 1:  Loss:     1.9427  Validation Accuracy: 0.347200
# Epoch 87, CIFAR-10 Batch 1:  Loss:     1.9919  Validation Accuracy: 0.371400
# Epoch 88, CIFAR-10 Batch 1:  Loss:     1.7441  Validation Accuracy: 0.334200
# Epoch 89, CIFAR-10 Batch 1:  Loss:     1.8917  Validation Accuracy: 0.320200
# Epoch 90, CIFAR-10 Batch 1:  Loss:     1.7538  Validation Accuracy: 0.353200
# Epoch 91, CIFAR-10 Batch 1:  Loss:     1.9239  Validation Accuracy: 0.331000
# Epoch 92, CIFAR-10 Batch 1:  Loss:     1.8244  Validation Accuracy: 0.274600
# Epoch 93, CIFAR-10 Batch 1:  Loss:     1.7465  Validation Accuracy: 0.364600
# Epoch 94, CIFAR-10 Batch 1:  Loss:     1.7739  Validation Accuracy: 0.368200
# Epoch 95, CIFAR-10 Batch 1:  Loss:     1.8208  Validation Accuracy: 0.369800
# Epoch 96, CIFAR-10 Batch 1:  Loss:     1.9732  Validation Accuracy: 0.363600
# Epoch 97, CIFAR-10 Batch 1:  Loss:     1.7859  Validation Accuracy: 0.364000
# Epoch 98, CIFAR-10 Batch 1:  Loss:     1.8607  Validation Accuracy: 0.365000
# Epoch 99, CIFAR-10 Batch 1:  Loss:     1.7368  Validation Accuracy: 0.369400
# Epoch 100, CIFAR-10 Batch 1:  Loss:     1.7959  Validation Accuracy: 0.382800

# %% [markdown]
# ### Fully Train the Model
# Now that you got a good accuracy with a single CIFAR-10 batch, try it with all five batches.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:  Loss:     2.3033  Validation Accuracy: 0.105000
# Epoch  1, CIFAR-10 Batch 2:  Loss:     2.3028  Validation Accuracy: 0.099800
# Epoch  1, CIFAR-10 Batch 3:  Loss:     2.3014  Validation Accuracy: 0.099800
# Epoch  1, CIFAR-10 Batch 4:  Loss:     2.2999  Validation Accuracy: 0.097000
# Epoch  1, CIFAR-10 Batch 5:  Loss:     2.2986  Validation Accuracy: 0.097000
# Epoch  2, CIFAR-10 Batch 1:  Loss:     2.3010  Validation Accuracy: 0.095800
# Epoch  2, CIFAR-10 Batch 2:  Loss:     2.3034  Validation Accuracy: 0.102000
# Epoch  2, CIFAR-10 Batch 3:  Loss:     2.3003  Validation Accuracy: 0.094200
# Epoch  2, CIFAR-10 Batch 4:  Loss:     2.3004  Validation Accuracy: 0.094200
# Epoch  2, CIFAR-10 Batch 5:  Loss:     2.2942  Validation Accuracy: 0.110400
# Epoch  3, CIFAR-10 Batch 1:  Loss:     2.2808  Validation Accuracy: 0.105200
# Epoch  3, CIFAR-10 Batch 2:  Loss:     2.1923  Validation Accuracy: 0.210000
# Epoch  3, CIFAR-10 Batch 3:  Loss:     2.0994  Validation Accuracy: 0.154200
# Epoch  3, CIFAR-10 Batch 4:  Loss:     2.1997  Validation Accuracy: 0.176400
# Epoch  3, CIFAR-10 Batch 5:  Loss:     2.2571  Validation Accuracy: 0.178000
# Epoch  4, CIFAR-10 Batch 1:  Loss:     2.2700  Validation Accuracy: 0.161400
# Epoch  4, CIFAR-10 Batch 2:  Loss:     2.1907  Validation Accuracy: 0.214800
# Epoch  4, CIFAR-10 Batch 3:  Loss:     2.0453  Validation Accuracy: 0.216200
# Epoch  4, CIFAR-10 Batch 4:  Loss:     2.1039  Validation Accuracy: 0.212200
# Epoch  4, CIFAR-10 Batch 5:  Loss:     2.3359  Validation Accuracy: 0.174200
# Epoch  5, CIFAR-10 Batch 1:  Loss:     2.2431  Validation Accuracy: 0.202400
# Epoch  5, CIFAR-10 Batch 2:  Loss:     2.1485  Validation Accuracy: 0.212000
# Epoch  5, CIFAR-10 Batch 3:  Loss:     1.9593  Validation Accuracy: 0.187000
# Epoch  5, CIFAR-10 Batch 4:  Loss:     2.0948  Validation Accuracy: 0.219600
# Epoch  5, CIFAR-10 Batch 5:  Loss:     2.3326  Validation Accuracy: 0.223000
# Epoch  6, CIFAR-10 Batch 1:  Loss:     2.2680  Validation Accuracy: 0.214600
# Epoch  6, CIFAR-10 Batch 2:  Loss:     2.1224  Validation Accuracy: 0.226400
# Epoch  6, CIFAR-10 Batch 3:  Loss:     2.0415  Validation Accuracy: 0.142600
# Epoch  6, CIFAR-10 Batch 4:  Loss:     2.0833  Validation Accuracy: 0.202400
# Epoch  6, CIFAR-10 Batch 5:  Loss:     2.2867  Validation Accuracy: 0.213600
# Epoch  7, CIFAR-10 Batch 1:  Loss:     2.2645  Validation Accuracy: 0.198200
# Epoch  7, CIFAR-10 Batch 2:  Loss:     2.1385  Validation Accuracy: 0.227600
# Epoch  7, CIFAR-10 Batch 3:  Loss:     1.9927  Validation Accuracy: 0.201200
# Epoch  7, CIFAR-10 Batch 4:  Loss:     2.0802  Validation Accuracy: 0.200600
# Epoch  7, CIFAR-10 Batch 5:  Loss:     2.3008  Validation Accuracy: 0.239000
# Epoch  8, CIFAR-10 Batch 1:  Loss:     2.2417  Validation Accuracy: 0.173400
# Epoch  8, CIFAR-10 Batch 2:  Loss:     2.1327  Validation Accuracy: 0.225200
# Epoch  8, CIFAR-10 Batch 3:  Loss:     1.9171  Validation Accuracy: 0.257000
# Epoch  8, CIFAR-10 Batch 4:  Loss:     2.0292  Validation Accuracy: 0.220400
# Epoch  8, CIFAR-10 Batch 5:  Loss:     2.1721  Validation Accuracy: 0.250800
# Epoch  9, CIFAR-10 Batch 1:  Loss:     2.2316  Validation Accuracy: 0.247000
# Epoch  9, CIFAR-10 Batch 2:  Loss:     2.1074  Validation Accuracy: 0.227600
# Epoch  9, CIFAR-10 Batch 3:  Loss:     1.9250  Validation Accuracy: 0.193200
# Epoch  9, CIFAR-10 Batch 4:  Loss:     1.9881  Validation Accuracy: 0.214400
# Epoch  9, CIFAR-10 Batch 5:  Loss:     2.3731  Validation Accuracy: 0.202200
# Epoch 10, CIFAR-10 Batch 1:  Loss:     2.1523  Validation Accuracy: 0.253200
# Epoch 10, CIFAR-10 Batch 2:  Loss:     2.1252  Validation Accuracy: 0.251000
# Epoch 10, CIFAR-10 Batch 3:  Loss:     1.9602  Validation Accuracy: 0.265600
# Epoch 10, CIFAR-10 Batch 4:  Loss:     1.9388  Validation Accuracy: 0.245200
# Epoch 10, CIFAR-10 Batch 5:  Loss:     2.1416  Validation Accuracy: 0.270200
# Epoch 11, CIFAR-10 Batch 1:  Loss:     2.1743  Validation Accuracy: 0.251200
# Epoch 11, CIFAR-10 Batch 2:  Loss:     2.0683  Validation Accuracy: 0.265800
# Epoch 11, CIFAR-10 Batch 3:  Loss:     1.8968  Validation Accuracy: 0.285000
# Epoch 11, CIFAR-10 Batch 4:  Loss:     1.9964  Validation Accuracy: 0.269600
# Epoch 11, CIFAR-10 Batch 5:  Loss:     2.0903  Validation Accuracy: 0.273600
# Epoch 12, CIFAR-10 Batch 1:  Loss:     2.1521  Validation Accuracy: 0.231600
# Epoch 12, CIFAR-10 Batch 2:  Loss:     2.0900  Validation Accuracy: 0.274600
# Epoch 12, CIFAR-10 Batch 3:  Loss:     1.8716  Validation Accuracy: 0.265000
# Epoch 12, CIFAR-10 Batch 4:  Loss:     1.9131  Validation Accuracy: 0.286200
# Epoch 12, CIFAR-10 Batch 5:  Loss:     2.2297  Validation Accuracy: 0.295400
# Epoch 13, CIFAR-10 Batch 1:  Loss:     2.1320  Validation Accuracy: 0.275600
# Epoch 13, CIFAR-10 Batch 2:  Loss:     2.0404  Validation Accuracy: 0.275600
# Epoch 13, CIFAR-10 Batch 3:  Loss:     1.8637  Validation Accuracy: 0.227600
# Epoch 13, CIFAR-10 Batch 4:  Loss:     1.8391  Validation Accuracy: 0.282600
# Epoch 13, CIFAR-10 Batch 5:  Loss:     2.2544  Validation Accuracy: 0.253400
# Epoch 14, CIFAR-10 Batch 1:  Loss:     2.1069  Validation Accuracy: 0.292600
# Epoch 14, CIFAR-10 Batch 2:  Loss:     1.8666  Validation Accuracy: 0.308200
# Epoch 14, CIFAR-10 Batch 3:  Loss:     1.6435  Validation Accuracy: 0.299000
# Epoch 14, CIFAR-10 Batch 4:  Loss:     1.7641  Validation Accuracy: 0.318800
# Epoch 14, CIFAR-10 Batch 5:  Loss:     2.1684  Validation Accuracy: 0.329200
# Epoch 15, CIFAR-10 Batch 1:  Loss:     2.1231  Validation Accuracy: 0.306800
# Epoch 15, CIFAR-10 Batch 2:  Loss:     1.8877  Validation Accuracy: 0.311200
# Epoch 15, CIFAR-10 Batch 3:  Loss:     1.8327  Validation Accuracy: 0.310800
# Epoch 15, CIFAR-10 Batch 4:  Loss:     1.8417  Validation Accuracy: 0.331000
# Epoch 15, CIFAR-10 Batch 5:  Loss:     2.0107  Validation Accuracy: 0.300600
# Epoch 16, CIFAR-10 Batch 1:  Loss:     2.0941  Validation Accuracy: 0.321000
# Epoch 16, CIFAR-10 Batch 2:  Loss:     1.8971  Validation Accuracy: 0.311400
# Epoch 16, CIFAR-10 Batch 3:  Loss:     1.7008  Validation Accuracy: 0.319800
# Epoch 16, CIFAR-10 Batch 4:  Loss:     1.9135  Validation Accuracy: 0.312600
# Epoch 16, CIFAR-10 Batch 5:  Loss:     1.9496  Validation Accuracy: 0.283600
# Epoch 17, CIFAR-10 Batch 1:  Loss:     2.1020  Validation Accuracy: 0.338200
# Epoch 17, CIFAR-10 Batch 2:  Loss:     1.8905  Validation Accuracy: 0.346600
# Epoch 17, CIFAR-10 Batch 3:  Loss:     1.6090  Validation Accuracy: 0.326600
# Epoch 17, CIFAR-10 Batch 4:  Loss:     1.7021  Validation Accuracy: 0.318600
# Epoch 17, CIFAR-10 Batch 5:  Loss:     1.8820  Validation Accuracy: 0.318600
# Epoch 18, CIFAR-10 Batch 1:  Loss:     2.0396  Validation Accuracy: 0.345400
# Epoch 18, CIFAR-10 Batch 2:  Loss:     1.8901  Validation Accuracy: 0.328200
# Epoch 18, CIFAR-10 Batch 3:  Loss:     1.6297  Validation Accuracy: 0.328000
# Epoch 18, CIFAR-10 Batch 4:  Loss:     1.6742  Validation Accuracy: 0.325800
# Epoch 18, CIFAR-10 Batch 5:  Loss:     1.9308  Validation Accuracy: 0.322200
# Epoch 19, CIFAR-10 Batch 1:  Loss:     2.0532  Validation Accuracy: 0.345800
# Epoch 19, CIFAR-10 Batch 2:  Loss:     1.8731  Validation Accuracy: 0.335400
# Epoch 19, CIFAR-10 Batch 3:  Loss:     1.7697  Validation Accuracy: 0.322800
# Epoch 19, CIFAR-10 Batch 4:  Loss:     1.7265  Validation Accuracy: 0.315200
# Epoch 19, CIFAR-10 Batch 5:  Loss:     1.9022  Validation Accuracy: 0.337800
# Epoch 20, CIFAR-10 Batch 1:  Loss:     1.9862  Validation Accuracy: 0.366800
# Epoch 20, CIFAR-10 Batch 2:  Loss:     1.8531  Validation Accuracy: 0.354200
# Epoch 20, CIFAR-10 Batch 3:  Loss:     1.5686  Validation Accuracy: 0.348800
# Epoch 20, CIFAR-10 Batch 4:  Loss:     1.6758  Validation Accuracy: 0.362200
# Epoch 20, CIFAR-10 Batch 5:  Loss:     1.9216  Validation Accuracy: 0.339400
# Epoch 21, CIFAR-10 Batch 1:  Loss:     2.0817  Validation Accuracy: 0.352000
# Epoch 21, CIFAR-10 Batch 2:  Loss:     1.8844  Validation Accuracy: 0.365400
# Epoch 21, CIFAR-10 Batch 3:  Loss:     1.6589  Validation Accuracy: 0.355600
# Epoch 21, CIFAR-10 Batch 4:  Loss:     1.6579  Validation Accuracy: 0.335400
# Epoch 21, CIFAR-10 Batch 5:  Loss:     1.9367  Validation Accuracy: 0.365200
# Epoch 22, CIFAR-10 Batch 1:  Loss:     2.0056  Validation Accuracy: 0.357800
# Epoch 22, CIFAR-10 Batch 2:  Loss:     1.8006  Validation Accuracy: 0.367200
# Epoch 22, CIFAR-10 Batch 3:  Loss:     1.5863  Validation Accuracy: 0.343600
# Epoch 22, CIFAR-10 Batch 4:  Loss:     1.6503  Validation Accuracy: 0.332200
# Epoch 22, CIFAR-10 Batch 5:  Loss:     1.8875  Validation Accuracy: 0.372000
# Epoch 23, CIFAR-10 Batch 1:  Loss:     2.0575  Validation Accuracy: 0.387800
# Epoch 23, CIFAR-10 Batch 2:  Loss:     1.8216  Validation Accuracy: 0.381600
# Epoch 23, CIFAR-10 Batch 3:  Loss:     1.5722  Validation Accuracy: 0.345800
# Epoch 23, CIFAR-10 Batch 4:  Loss:     1.7225  Validation Accuracy: 0.382800
# Epoch 23, CIFAR-10 Batch 5:  Loss:     1.8941  Validation Accuracy: 0.385200
# Epoch 24, CIFAR-10 Batch 1:  Loss:     1.8453  Validation Accuracy: 0.379400
# Epoch 24, CIFAR-10 Batch 2:  Loss:     1.8316  Validation Accuracy: 0.384800
# Epoch 24, CIFAR-10 Batch 3:  Loss:     1.5539  Validation Accuracy: 0.374000
# Epoch 24, CIFAR-10 Batch 4:  Loss:     1.5310  Validation Accuracy: 0.385600
# Epoch 24, CIFAR-10 Batch 5:  Loss:     1.8289  Validation Accuracy: 0.356800
# Epoch 25, CIFAR-10 Batch 1:  Loss:     1.8729  Validation Accuracy: 0.384600
# Epoch 25, CIFAR-10 Batch 2:  Loss:     1.6776  Validation Accuracy: 0.385600
# Epoch 25, CIFAR-10 Batch 3:  Loss:     1.4146  Validation Accuracy: 0.386600
# Epoch 25, CIFAR-10 Batch 4:  Loss:     1.5868  Validation Accuracy: 0.357600
# Epoch 25, CIFAR-10 Batch 5:  Loss:     1.8483  Validation Accuracy: 0.387600
# Epoch 26, CIFAR-10 Batch 1:  Loss:     1.9513  Validation Accuracy: 0.382400
# Epoch 26, CIFAR-10 Batch 2:  Loss:     1.9824  Validation Accuracy: 0.391400
# Epoch 26, CIFAR-10 Batch 3:  Loss:     1.5212  Validation Accuracy: 0.384000
# Epoch 26, CIFAR-10 Batch 4:  Loss:     1.5533  Validation Accuracy: 0.396200
# Epoch 26, CIFAR-10 Batch 5:  Loss:     1.6959  Validation Accuracy: 0.318600
# Epoch 27, CIFAR-10 Batch 1:  Loss:     1.9612  Validation Accuracy: 0.347200
# Epoch 27, CIFAR-10 Batch 2:  Loss:     1.7740  Validation Accuracy: 0.406800
# Epoch 27, CIFAR-10 Batch 3:  Loss:     1.5261  Validation Accuracy: 0.399000
# Epoch 27, CIFAR-10 Batch 4:  Loss:     1.5670  Validation Accuracy: 0.383000
# Epoch 27, CIFAR-10 Batch 5:  Loss:     1.7173  Validation Accuracy: 0.383800
# Epoch 28, CIFAR-10 Batch 1:  Loss:     2.1642  Validation Accuracy: 0.410600
# Epoch 28, CIFAR-10 Batch 2:  Loss:     1.7939  Validation Accuracy: 0.402800
# Epoch 28, CIFAR-10 Batch 3:  Loss:     1.5551  Validation Accuracy: 0.380800
# Epoch 28, CIFAR-10 Batch 4:  Loss:     1.5676  Validation Accuracy: 0.359200
# Epoch 28, CIFAR-10 Batch 5:  Loss:     1.6913  Validation Accuracy: 0.375000
# Epoch 29, CIFAR-10 Batch 1:  Loss:     1.8684  Validation Accuracy: 0.408600
# Epoch 29, CIFAR-10 Batch 2:  Loss:     1.7403  Validation Accuracy: 0.399000
# Epoch 29, CIFAR-10 Batch 3:  Loss:     1.5328  Validation Accuracy: 0.392800
# Epoch 29, CIFAR-10 Batch 4:  Loss:     1.4613  Validation Accuracy: 0.403600
# Epoch 29, CIFAR-10 Batch 5:  Loss:     1.8379  Validation Accuracy: 0.401600
# Epoch 30, CIFAR-10 Batch 1:  Loss:     1.7582  Validation Accuracy: 0.389800
# Epoch 30, CIFAR-10 Batch 2:  Loss:     1.7346  Validation Accuracy: 0.392600
# Epoch 30, CIFAR-10 Batch 3:  Loss:     1.4139  Validation Accuracy: 0.411400
# Epoch 30, CIFAR-10 Batch 4:  Loss:     1.4277  Validation Accuracy: 0.403000
# Epoch 30, CIFAR-10 Batch 5:  Loss:     1.6359  Validation Accuracy: 0.409200
# Epoch 31, CIFAR-10 Batch 1:  Loss:     1.6537  Validation Accuracy: 0.412200
# Epoch 31, CIFAR-10 Batch 2:  Loss:     1.5979  Validation Accuracy: 0.414000
# Epoch 31, CIFAR-10 Batch 3:  Loss:     1.4448  Validation Accuracy: 0.402200
# Epoch 31, CIFAR-10 Batch 4:  Loss:     1.5134  Validation Accuracy: 0.423000
# Epoch 31, CIFAR-10 Batch 5:  Loss:     1.6708  Validation Accuracy: 0.391000
# Epoch 32, CIFAR-10 Batch 1:  Loss:     1.7323  Validation Accuracy: 0.401600
# Epoch 32, CIFAR-10 Batch 2:  Loss:     1.7320  Validation Accuracy: 0.384200
# Epoch 32, CIFAR-10 Batch 3:  Loss:     1.3533  Validation Accuracy: 0.397200
# Epoch 32, CIFAR-10 Batch 4:  Loss:     1.5283  Validation Accuracy: 0.419200
# Epoch 32, CIFAR-10 Batch 5:  Loss:     1.6649  Validation Accuracy: 0.403400
# Epoch 33, CIFAR-10 Batch 1:  Loss:     1.6928  Validation Accuracy: 0.434200
# Epoch 33, CIFAR-10 Batch 2:  Loss:     1.8348  Validation Accuracy: 0.407800
# Epoch 33, CIFAR-10 Batch 3:  Loss:     1.4141  Validation Accuracy: 0.427800
# Epoch 33, CIFAR-10 Batch 4:  Loss:     1.4747  Validation Accuracy: 0.434600
# Epoch 33, CIFAR-10 Batch 5:  Loss:     1.6577  Validation Accuracy: 0.430800
# Epoch 34, CIFAR-10 Batch 1:  Loss:     1.6906  Validation Accuracy: 0.435000
# Epoch 34, CIFAR-10 Batch 2:  Loss:     1.6584  Validation Accuracy: 0.415000
# Epoch 34, CIFAR-10 Batch 3:  Loss:     1.4032  Validation Accuracy: 0.421200
# Epoch 34, CIFAR-10 Batch 4:  Loss:     1.4623  Validation Accuracy: 0.427000
# Epoch 34, CIFAR-10 Batch 5:  Loss:     1.5785  Validation Accuracy: 0.424200
# Epoch 35, CIFAR-10 Batch 1:  Loss:     1.6839  Validation Accuracy: 0.416800
# Epoch 35, CIFAR-10 Batch 2:  Loss:     1.6939  Validation Accuracy: 0.434600
# Epoch 35, CIFAR-10 Batch 3:  Loss:     1.3928  Validation Accuracy: 0.406400
# Epoch 35, CIFAR-10 Batch 4:  Loss:     1.3351  Validation Accuracy: 0.443600
# Epoch 35, CIFAR-10 Batch 5:  Loss:     1.7248  Validation Accuracy: 0.435600
# Epoch 36, CIFAR-10 Batch 1:  Loss:     1.6562  Validation Accuracy: 0.450000
# Epoch 36, CIFAR-10 Batch 2:  Loss:     1.6419  Validation Accuracy: 0.426000
# Epoch 36, CIFAR-10 Batch 3:  Loss:     1.4158  Validation Accuracy: 0.446600
# Epoch 36, CIFAR-10 Batch 4:  Loss:     1.3841  Validation Accuracy: 0.438200
# Epoch 36, CIFAR-10 Batch 5:  Loss:     1.5720  Validation Accuracy: 0.417000
# Epoch 37, CIFAR-10 Batch 1:  Loss:     1.6303  Validation Accuracy: 0.430000
# Epoch 37, CIFAR-10 Batch 2:  Loss:     1.5935  Validation Accuracy: 0.444400
# Epoch 37, CIFAR-10 Batch 3:  Loss:     1.2925  Validation Accuracy: 0.427000
# Epoch 37, CIFAR-10 Batch 4:  Loss:     1.4261  Validation Accuracy: 0.434600
# Epoch 37, CIFAR-10 Batch 5:  Loss:     1.7654  Validation Accuracy: 0.425000
# Epoch 38, CIFAR-10 Batch 1:  Loss:     1.7716  Validation Accuracy: 0.411400
# Epoch 38, CIFAR-10 Batch 2:  Loss:     1.6104  Validation Accuracy: 0.426400
# Epoch 38, CIFAR-10 Batch 3:  Loss:     1.3172  Validation Accuracy: 0.434600
# Epoch 38, CIFAR-10 Batch 4:  Loss:     1.3436  Validation Accuracy: 0.438800
# Epoch 38, CIFAR-10 Batch 5:  Loss:     1.5073  Validation Accuracy: 0.451800
# Epoch 39, CIFAR-10 Batch 1:  Loss:     1.6160  Validation Accuracy: 0.421200
# Epoch 39, CIFAR-10 Batch 2:  Loss:     1.5682  Validation Accuracy: 0.433400
# Epoch 39, CIFAR-10 Batch 3:  Loss:     1.2246  Validation Accuracy: 0.436200
# Epoch 39, CIFAR-10 Batch 4:  Loss:     1.3622  Validation Accuracy: 0.444000
# Epoch 39, CIFAR-10 Batch 5:  Loss:     1.4694  Validation Accuracy: 0.446600
# Epoch 40, CIFAR-10 Batch 1:  Loss:     1.8145  Validation Accuracy: 0.436800
# Epoch 40, CIFAR-10 Batch 2:  Loss:     1.4851  Validation Accuracy: 0.425200
# Epoch 40, CIFAR-10 Batch 3:  Loss:     1.3003  Validation Accuracy: 0.419600
# Epoch 40, CIFAR-10 Batch 4:  Loss:     1.2459  Validation Accuracy: 0.427400
# Epoch 40, CIFAR-10 Batch 5:  Loss:     1.4304  Validation Accuracy: 0.447200
# Epoch 41, CIFAR-10 Batch 1:  Loss:     1.5525  Validation Accuracy: 0.447000
# Epoch 41, CIFAR-10 Batch 2:  Loss:     1.5363  Validation Accuracy: 0.453600
# Epoch 41, CIFAR-10 Batch 3:  Loss:     1.2714  Validation Accuracy: 0.433800
# Epoch 41, CIFAR-10 Batch 4:  Loss:     1.2856  Validation Accuracy: 0.442600
# Epoch 41, CIFAR-10 Batch 5:  Loss:     1.4422  Validation Accuracy: 0.456000
# Epoch 42, CIFAR-10 Batch 1:  Loss:     1.5314  Validation Accuracy: 0.462200
# Epoch 42, CIFAR-10 Batch 2:  Loss:     1.4977  Validation Accuracy: 0.443200
# Epoch 42, CIFAR-10 Batch 3:  Loss:     1.2900  Validation Accuracy: 0.425400
# Epoch 42, CIFAR-10 Batch 4:  Loss:     1.2882  Validation Accuracy: 0.460200
# Epoch 42, CIFAR-10 Batch 5:  Loss:     1.5902  Validation Accuracy: 0.429600
# Epoch 43, CIFAR-10 Batch 1:  Loss:     1.8067  Validation Accuracy: 0.445200
# Epoch 43, CIFAR-10 Batch 2:  Loss:     1.5363  Validation Accuracy: 0.440000
# Epoch 43, CIFAR-10 Batch 3:  Loss:     1.2325  Validation Accuracy: 0.452200
# Epoch 43, CIFAR-10 Batch 4:  Loss:     1.3380  Validation Accuracy: 0.462400
# Epoch 43, CIFAR-10 Batch 5:  Loss:     1.4366  Validation Accuracy: 0.436000
# Epoch 44, CIFAR-10 Batch 1:  Loss:     1.4625  Validation Accuracy: 0.451400
# Epoch 44, CIFAR-10 Batch 2:  Loss:     1.5056  Validation Accuracy: 0.443600
# Epoch 44, CIFAR-10 Batch 3:  Loss:     1.2630  Validation Accuracy: 0.444400
# Epoch 44, CIFAR-10 Batch 4:  Loss:     1.3579  Validation Accuracy: 0.435800
# Epoch 44, CIFAR-10 Batch 5:  Loss:     1.4578  Validation Accuracy: 0.433800
# Epoch 45, CIFAR-10 Batch 1:  Loss:     1.4443  Validation Accuracy: 0.455400
# Epoch 45, CIFAR-10 Batch 2:  Loss:     1.4351  Validation Accuracy: 0.444600
# Epoch 45, CIFAR-10 Batch 3:  Loss:     1.2454  Validation Accuracy: 0.464800
# Epoch 45, CIFAR-10 Batch 4:  Loss:     1.3482  Validation Accuracy: 0.458800
# Epoch 45, CIFAR-10 Batch 5:  Loss:     1.4879  Validation Accuracy: 0.458400
# Epoch 46, CIFAR-10 Batch 1:  Loss:     1.3696  Validation Accuracy: 0.465400
# Epoch 46, CIFAR-10 Batch 2:  Loss:     1.4166  Validation Accuracy: 0.467000
# Epoch 46, CIFAR-10 Batch 3:  Loss:     1.1717  Validation Accuracy: 0.462200
# Epoch 46, CIFAR-10 Batch 4:  Loss:     1.2774  Validation Accuracy: 0.461600
# Epoch 46, CIFAR-10 Batch 5:  Loss:     1.4618  Validation Accuracy: 0.452400
# Epoch 47, CIFAR-10 Batch 1:  Loss:     1.2911  Validation Accuracy: 0.469400
# Epoch 47, CIFAR-10 Batch 2:  Loss:     1.3773  Validation Accuracy: 0.449600
# Epoch 47, CIFAR-10 Batch 3:  Loss:     1.1589  Validation Accuracy: 0.451200
# Epoch 47, CIFAR-10 Batch 4:  Loss:     1.2767  Validation Accuracy: 0.465800
# Epoch 47, CIFAR-10 Batch 5:  Loss:     1.3480  Validation Accuracy: 0.458200
# Epoch 48, CIFAR-10 Batch 1:  Loss:     1.4086  Validation Accuracy: 0.434400
# Epoch 48, CIFAR-10 Batch 2:  Loss:     1.5463  Validation Accuracy: 0.471400
# Epoch 48, CIFAR-10 Batch 3:  Loss:     1.1421  Validation Accuracy: 0.464400
# Epoch 48, CIFAR-10 Batch 4:  Loss:     1.3214  Validation Accuracy: 0.460400
# Epoch 48, CIFAR-10 Batch 5:  Loss:     1.3048  Validation Accuracy: 0.458800
# Epoch 49, CIFAR-10 Batch 1:  Loss:     1.5246  Validation Accuracy: 0.482800
# Epoch 49, CIFAR-10 Batch 2:  Loss:     1.3332  Validation Accuracy: 0.445200
# Epoch 49, CIFAR-10 Batch 3:  Loss:     1.1558  Validation Accuracy: 0.441200
# Epoch 49, CIFAR-10 Batch 4:  Loss:     1.2189  Validation Accuracy: 0.465800
# Epoch 49, CIFAR-10 Batch 5:  Loss:     1.4966  Validation Accuracy: 0.465000
# Epoch 50, CIFAR-10 Batch 1:  Loss:     1.3119  Validation Accuracy: 0.482200
# Epoch 50, CIFAR-10 Batch 2:  Loss:     1.4630  Validation Accuracy: 0.463000
# Epoch 50, CIFAR-10 Batch 3:  Loss:     1.1348  Validation Accuracy: 0.462600
# Epoch 50, CIFAR-10 Batch 4:  Loss:     1.2141  Validation Accuracy: 0.467200
# Epoch 50, CIFAR-10 Batch 5:  Loss:     1.2765  Validation Accuracy: 0.429600
# Epoch 51, CIFAR-10 Batch 1:  Loss:     1.2844  Validation Accuracy: 0.453200
# Epoch 51, CIFAR-10 Batch 2:  Loss:     1.5072  Validation Accuracy: 0.476800
# Epoch 51, CIFAR-10 Batch 3:  Loss:     1.2177  Validation Accuracy: 0.438800
# Epoch 51, CIFAR-10 Batch 4:  Loss:     1.1606  Validation Accuracy: 0.460200
# Epoch 51, CIFAR-10 Batch 5:  Loss:     1.3846  Validation Accuracy: 0.457400
# Epoch 52, CIFAR-10 Batch 1:  Loss:     1.4083  Validation Accuracy: 0.474400
# Epoch 52, CIFAR-10 Batch 2:  Loss:     1.4743  Validation Accuracy: 0.448600
# Epoch 52, CIFAR-10 Batch 3:  Loss:     1.1059  Validation Accuracy: 0.458400
# Epoch 52, CIFAR-10 Batch 4:  Loss:     1.2563  Validation Accuracy: 0.480400
# Epoch 52, CIFAR-10 Batch 5:  Loss:     1.4695  Validation Accuracy: 0.465400
# Epoch 53, CIFAR-10 Batch 1:  Loss:     1.2566  Validation Accuracy: 0.483200
# Epoch 53, CIFAR-10 Batch 2:  Loss:     1.3872  Validation Accuracy: 0.488800
# Epoch 53, CIFAR-10 Batch 3:  Loss:     1.0802  Validation Accuracy: 0.464800
# Epoch 53, CIFAR-10 Batch 4:  Loss:     1.2291  Validation Accuracy: 0.486800
# Epoch 53, CIFAR-10 Batch 5:  Loss:     1.2927  Validation Accuracy: 0.476600
# Epoch 54, CIFAR-10 Batch 1:  Loss:     1.3709  Validation Accuracy: 0.479400
# Epoch 54, CIFAR-10 Batch 2:  Loss:     1.4480  Validation Accuracy: 0.468600
# Epoch 54, CIFAR-10 Batch 3:  Loss:     1.1354  Validation Accuracy: 0.462200
# Epoch 54, CIFAR-10 Batch 4:  Loss:     1.1582  Validation Accuracy: 0.482000
# Epoch 54, CIFAR-10 Batch 5:  Loss:     1.3337  Validation Accuracy: 0.467600
# Epoch 55, CIFAR-10 Batch 1:  Loss:     1.6974  Validation Accuracy: 0.412800
# Epoch 55, CIFAR-10 Batch 2:  Loss:     1.3509  Validation Accuracy: 0.464600
# Epoch 55, CIFAR-10 Batch 3:  Loss:     1.0441  Validation Accuracy: 0.477800
# Epoch 55, CIFAR-10 Batch 4:  Loss:     1.1559  Validation Accuracy: 0.474800
# Epoch 55, CIFAR-10 Batch 5:  Loss:     1.3143  Validation Accuracy: 0.487200
# Epoch 56, CIFAR-10 Batch 1:  Loss:     1.2071  Validation Accuracy: 0.476400
# Epoch 56, CIFAR-10 Batch 2:  Loss:     1.2610  Validation Accuracy: 0.479000
# Epoch 56, CIFAR-10 Batch 3:  Loss:     1.0928  Validation Accuracy: 0.470800
# Epoch 56, CIFAR-10 Batch 4:  Loss:     1.1726  Validation Accuracy: 0.474400
# Epoch 56, CIFAR-10 Batch 5:  Loss:     1.4475  Validation Accuracy: 0.481200
# Epoch 57, CIFAR-10 Batch 1:  Loss:     1.1487  Validation Accuracy: 0.483600
# Epoch 57, CIFAR-10 Batch 2:  Loss:     1.2073  Validation Accuracy: 0.426200
# Epoch 57, CIFAR-10 Batch 3:  Loss:     1.1212  Validation Accuracy: 0.476000
# Epoch 57, CIFAR-10 Batch 4:  Loss:     1.1305  Validation Accuracy: 0.464000
# Epoch 57, CIFAR-10 Batch 5:  Loss:     1.3030  Validation Accuracy: 0.468200
# Epoch 58, CIFAR-10 Batch 1:  Loss:     1.2071  Validation Accuracy: 0.482800
# Epoch 58, CIFAR-10 Batch 2:  Loss:     1.2789  Validation Accuracy: 0.477000
# Epoch 58, CIFAR-10 Batch 3:  Loss:     1.0474  Validation Accuracy: 0.468000
# Epoch 58, CIFAR-10 Batch 4:  Loss:     1.1015  Validation Accuracy: 0.487800
# Epoch 58, CIFAR-10 Batch 5:  Loss:     1.1915  Validation Accuracy: 0.475200
# Epoch 59, CIFAR-10 Batch 1:  Loss:     1.1961  Validation Accuracy: 0.480400
# Epoch 59, CIFAR-10 Batch 2:  Loss:     1.2530  Validation Accuracy: 0.476400
# Epoch 59, CIFAR-10 Batch 3:  Loss:     1.1413  Validation Accuracy: 0.495800
# Epoch 59, CIFAR-10 Batch 4:  Loss:     1.0590  Validation Accuracy: 0.497000
# Epoch 59, CIFAR-10 Batch 5:  Loss:     1.2723  Validation Accuracy: 0.504000
# Epoch 60, CIFAR-10 Batch 1:  Loss:     1.2727  Validation Accuracy: 0.483800
# Epoch 60, CIFAR-10 Batch 2:  Loss:     1.5664  Validation Accuracy: 0.484800
# Epoch 60, CIFAR-10 Batch 3:  Loss:     0.9920  Validation Accuracy: 0.489600
# Epoch 60, CIFAR-10 Batch 4:  Loss:     1.0979  Validation Accuracy: 0.470000
# Epoch 60, CIFAR-10 Batch 5:  Loss:     1.2085  Validation Accuracy: 0.483400
# Epoch 61, CIFAR-10 Batch 1:  Loss:     1.2072  Validation Accuracy: 0.500800
# Epoch 61, CIFAR-10 Batch 2:  Loss:     1.3618  Validation Accuracy: 0.476400
# Epoch 61, CIFAR-10 Batch 3:  Loss:     1.0227  Validation Accuracy: 0.493800
# Epoch 61, CIFAR-10 Batch 4:  Loss:     1.1132  Validation Accuracy: 0.487600
# Epoch 61, CIFAR-10 Batch 5:  Loss:     1.1857  Validation Accuracy: 0.492000
# Epoch 62, CIFAR-10 Batch 1:  Loss:     1.1721  Validation Accuracy: 0.491200
# Epoch 62, CIFAR-10 Batch 2:  Loss:     1.2064  Validation Accuracy: 0.486400
# Epoch 62, CIFAR-10 Batch 3:  Loss:     1.0678  Validation Accuracy: 0.486000
# Epoch 62, CIFAR-10 Batch 4:  Loss:     1.2292  Validation Accuracy: 0.481400
# Epoch 62, CIFAR-10 Batch 5:  Loss:     1.1711  Validation Accuracy: 0.483000
# Epoch 63, CIFAR-10 Batch 1:  Loss:     1.2747  Validation Accuracy: 0.489800
# Epoch 63, CIFAR-10 Batch 2:  Loss:     1.3260  Validation Accuracy: 0.479800
# Epoch 63, CIFAR-10 Batch 3:  Loss:     1.0295  Validation Accuracy: 0.481200
# Epoch 63, CIFAR-10 Batch 4:  Loss:     1.0928  Validation Accuracy: 0.500600
# Epoch 63, CIFAR-10 Batch 5:  Loss:     1.1455  Validation Accuracy: 0.486600
# Epoch 64, CIFAR-10 Batch 1:  Loss:     1.1906  Validation Accuracy: 0.504000
# Epoch 64, CIFAR-10 Batch 2:  Loss:     1.1750  Validation Accuracy: 0.503400
# Epoch 64, CIFAR-10 Batch 3:  Loss:     1.1151  Validation Accuracy: 0.480400
# Epoch 64, CIFAR-10 Batch 4:  Loss:     1.0645  Validation Accuracy: 0.507400
# Epoch 64, CIFAR-10 Batch 5:  Loss:     1.1090  Validation Accuracy: 0.490400
# Epoch 65, CIFAR-10 Batch 1:  Loss:     1.1246  Validation Accuracy: 0.482200
# Epoch 65, CIFAR-10 Batch 2:  Loss:     1.3810  Validation Accuracy: 0.471000
# Epoch 65, CIFAR-10 Batch 3:  Loss:     1.0077  Validation Accuracy: 0.496800
# Epoch 65, CIFAR-10 Batch 4:  Loss:     1.1012  Validation Accuracy: 0.500600
# Epoch 65, CIFAR-10 Batch 5:  Loss:     1.2001  Validation Accuracy: 0.498200
# Epoch 66, CIFAR-10 Batch 1:  Loss:     1.0836  Validation Accuracy: 0.493200
# Epoch 66, CIFAR-10 Batch 2:  Loss:     1.1587  Validation Accuracy: 0.495200
# Epoch 66, CIFAR-10 Batch 3:  Loss:     1.0375  Validation Accuracy: 0.433000
# Epoch 66, CIFAR-10 Batch 4:  Loss:     1.0705  Validation Accuracy: 0.503000
# Epoch 66, CIFAR-10 Batch 5:  Loss:     1.1116  Validation Accuracy: 0.481400
# Epoch 67, CIFAR-10 Batch 1:  Loss:     1.0781  Validation Accuracy: 0.497400
# Epoch 67, CIFAR-10 Batch 2:  Loss:     1.2388  Validation Accuracy: 0.488200
# Epoch 67, CIFAR-10 Batch 3:  Loss:     0.9292  Validation Accuracy: 0.504200
# Epoch 67, CIFAR-10 Batch 4:  Loss:     1.0552  Validation Accuracy: 0.497400
# Epoch 67, CIFAR-10 Batch 5:  Loss:     1.1535  Validation Accuracy: 0.486400
# Epoch 68, CIFAR-10 Batch 1:  Loss:     1.1059  Validation Accuracy: 0.498200
# Epoch 68, CIFAR-10 Batch 2:  Loss:     1.0826  Validation Accuracy: 0.499800
# Epoch 68, CIFAR-10 Batch 3:  Loss:     0.9966  Validation Accuracy: 0.503800
# Epoch 68, CIFAR-10 Batch 4:  Loss:     1.0709  Validation Accuracy: 0.509200
# Epoch 68, CIFAR-10 Batch 5:  Loss:     1.1639  Validation Accuracy: 0.468800
# Epoch 69, CIFAR-10 Batch 1:  Loss:     1.0673  Validation Accuracy: 0.504400
# Epoch 69, CIFAR-10 Batch 2:  Loss:     1.1748  Validation Accuracy: 0.512000
# Epoch 69, CIFAR-10 Batch 3:  Loss:     0.9775  Validation Accuracy: 0.463000
# Epoch 69, CIFAR-10 Batch 4:  Loss:     1.0197  Validation Accuracy: 0.507200
# Epoch 69, CIFAR-10 Batch 5:  Loss:     1.1189  Validation Accuracy: 0.498600
# Epoch 70, CIFAR-10 Batch 1:  Loss:     1.0835  Validation Accuracy: 0.470600
# Epoch 70, CIFAR-10 Batch 2:  Loss:     1.1953  Validation Accuracy: 0.497000
# Epoch 70, CIFAR-10 Batch 3:  Loss:     1.0106  Validation Accuracy: 0.504000
# Epoch 70, CIFAR-10 Batch 4:  Loss:     0.9738  Validation Accuracy: 0.517200
# Epoch 70, CIFAR-10 Batch 5:  Loss:     1.0389  Validation Accuracy: 0.507400
# Epoch 71, CIFAR-10 Batch 1:  Loss:     0.9833  Validation Accuracy: 0.478000
# Epoch 71, CIFAR-10 Batch 2:  Loss:     1.1472  Validation Accuracy: 0.509600
# Epoch 71, CIFAR-10 Batch 3:  Loss:     0.8853  Validation Accuracy: 0.489800
# Epoch 71, CIFAR-10 Batch 4:  Loss:     0.9683  Validation Accuracy: 0.486800
# Epoch 71, CIFAR-10 Batch 5:  Loss:     1.0392  Validation Accuracy: 0.510000
# Epoch 72, CIFAR-10 Batch 1:  Loss:     1.0040  Validation Accuracy: 0.517000
# Epoch 72, CIFAR-10 Batch 2:  Loss:     0.9942  Validation Accuracy: 0.510000
# Epoch 72, CIFAR-10 Batch 3:  Loss:     1.1228  Validation Accuracy: 0.483000
# Epoch 72, CIFAR-10 Batch 4:  Loss:     0.9818  Validation Accuracy: 0.513200
# Epoch 72, CIFAR-10 Batch 5:  Loss:     1.0739  Validation Accuracy: 0.467200
# Epoch 73, CIFAR-10 Batch 1:  Loss:     1.0887  Validation Accuracy: 0.518200
# Epoch 73, CIFAR-10 Batch 2:  Loss:     1.1602  Validation Accuracy: 0.510000
# Epoch 73, CIFAR-10 Batch 3:  Loss:     0.8755  Validation Accuracy: 0.505400
# Epoch 73, CIFAR-10 Batch 4:  Loss:     0.9718  Validation Accuracy: 0.510800
# Epoch 73, CIFAR-10 Batch 5:  Loss:     1.0526  Validation Accuracy: 0.496400
# Epoch 74, CIFAR-10 Batch 1:  Loss:     1.0368  Validation Accuracy: 0.504400
# Epoch 74, CIFAR-10 Batch 2:  Loss:     1.0180  Validation Accuracy: 0.508400
# Epoch 74, CIFAR-10 Batch 3:  Loss:     0.9281  Validation Accuracy: 0.507800
# Epoch 74, CIFAR-10 Batch 4:  Loss:     0.9653  Validation Accuracy: 0.486600
# Epoch 74, CIFAR-10 Batch 5:  Loss:     1.0640  Validation Accuracy: 0.484000
# Epoch 75, CIFAR-10 Batch 1:  Loss:     0.9856  Validation Accuracy: 0.509000
# Epoch 75, CIFAR-10 Batch 2:  Loss:     1.0049  Validation Accuracy: 0.500000
# Epoch 75, CIFAR-10 Batch 3:  Loss:     0.9855  Validation Accuracy: 0.499600
# Epoch 75, CIFAR-10 Batch 4:  Loss:     0.9947  Validation Accuracy: 0.517000
# Epoch 75, CIFAR-10 Batch 5:  Loss:     1.1346  Validation Accuracy: 0.507800
# Epoch 76, CIFAR-10 Batch 1:  Loss:     1.3357  Validation Accuracy: 0.513400
# Epoch 76, CIFAR-10 Batch 2:  Loss:     1.0791  Validation Accuracy: 0.519000
# Epoch 76, CIFAR-10 Batch 3:  Loss:     0.8730  Validation Accuracy: 0.519000
# Epoch 76, CIFAR-10 Batch 4:  Loss:     0.9881  Validation Accuracy: 0.507600
# Epoch 76, CIFAR-10 Batch 5:  Loss:     1.0423  Validation Accuracy: 0.511600
# Epoch 77, CIFAR-10 Batch 1:  Loss:     1.0340  Validation Accuracy: 0.504800
# Epoch 77, CIFAR-10 Batch 2:  Loss:     1.0014  Validation Accuracy: 0.518000
# Epoch 77, CIFAR-10 Batch 3:  Loss:     0.9140  Validation Accuracy: 0.488600
# Epoch 77, CIFAR-10 Batch 4:  Loss:     0.9512  Validation Accuracy: 0.522000
# Epoch 77, CIFAR-10 Batch 5:  Loss:     0.9763  Validation Accuracy: 0.489800
# Epoch 78, CIFAR-10 Batch 1:  Loss:     1.0168  Validation Accuracy: 0.516200
# Epoch 78, CIFAR-10 Batch 2:  Loss:     0.9608  Validation Accuracy: 0.502400
# Epoch 78, CIFAR-10 Batch 3:  Loss:     0.8255  Validation Accuracy: 0.493400
# Epoch 78, CIFAR-10 Batch 4:  Loss:     0.9782  Validation Accuracy: 0.523000
# Epoch 78, CIFAR-10 Batch 5:  Loss:     1.2039  Validation Accuracy: 0.495000
# Epoch 79, CIFAR-10 Batch 1:  Loss:     0.8850  Validation Accuracy: 0.521000
# Epoch 79, CIFAR-10 Batch 2:  Loss:     1.0509  Validation Accuracy: 0.505400
# Epoch 79, CIFAR-10 Batch 3:  Loss:     0.8953  Validation Accuracy: 0.512600
# Epoch 79, CIFAR-10 Batch 4:  Loss:     1.0364  Validation Accuracy: 0.520000
# Epoch 79, CIFAR-10 Batch 5:  Loss:     1.0069  Validation Accuracy: 0.510400
# Epoch 80, CIFAR-10 Batch 1:  Loss:     1.0609  Validation Accuracy: 0.499400
# Epoch 80, CIFAR-10 Batch 2:  Loss:     1.0987  Validation Accuracy: 0.511200
# Epoch 80, CIFAR-10 Batch 3:  Loss:     0.8557  Validation Accuracy: 0.510000
# Epoch 80, CIFAR-10 Batch 4:  Loss:     0.9682  Validation Accuracy: 0.513400
# Epoch 80, CIFAR-10 Batch 5:  Loss:     1.0343  Validation Accuracy: 0.515800
# Epoch 81, CIFAR-10 Batch 1:  Loss:     0.9863  Validation Accuracy: 0.487800
# Epoch 81, CIFAR-10 Batch 2:  Loss:     1.0979  Validation Accuracy: 0.515800
# Epoch 81, CIFAR-10 Batch 3:  Loss:     0.8680  Validation Accuracy: 0.492200
# Epoch 81, CIFAR-10 Batch 4:  Loss:     0.9088  Validation Accuracy: 0.514200
# Epoch 81, CIFAR-10 Batch 5:  Loss:     0.9381  Validation Accuracy: 0.521800
# Epoch 82, CIFAR-10 Batch 1:  Loss:     1.0243  Validation Accuracy: 0.514200
# Epoch 82, CIFAR-10 Batch 2:  Loss:     0.9346  Validation Accuracy: 0.510400
# Epoch 82, CIFAR-10 Batch 3:  Loss:     0.8948  Validation Accuracy: 0.491600
# Epoch 82, CIFAR-10 Batch 4:  Loss:     0.9231  Validation Accuracy: 0.526200
# Epoch 82, CIFAR-10 Batch 5:  Loss:     1.0312  Validation Accuracy: 0.507800
# Epoch 83, CIFAR-10 Batch 1:  Loss:     0.9069  Validation Accuracy: 0.515400
# Epoch 83, CIFAR-10 Batch 2:  Loss:     0.9657  Validation Accuracy: 0.510400
# Epoch 83, CIFAR-10 Batch 3:  Loss:     0.7874  Validation Accuracy: 0.493600
# Epoch 83, CIFAR-10 Batch 4:  Loss:     0.9354  Validation Accuracy: 0.521200
# Epoch 83, CIFAR-10 Batch 5:  Loss:     0.9009  Validation Accuracy: 0.522200
# Epoch 84, CIFAR-10 Batch 1:  Loss:     0.8791  Validation Accuracy: 0.528600
# Epoch 84, CIFAR-10 Batch 2:  Loss:     0.8946  Validation Accuracy: 0.513000
# Epoch 84, CIFAR-10 Batch 3:  Loss:     0.8440  Validation Accuracy: 0.518200
# Epoch 84, CIFAR-10 Batch 4:  Loss:     1.0018  Validation Accuracy: 0.517800
# Epoch 84, CIFAR-10 Batch 5:  Loss:     0.9914  Validation Accuracy: 0.514400
# Epoch 85, CIFAR-10 Batch 1:  Loss:     0.9883  Validation Accuracy: 0.518800
# Epoch 85, CIFAR-10 Batch 2:  Loss:     0.8467  Validation Accuracy: 0.498600
# Epoch 85, CIFAR-10 Batch 3:  Loss:     0.8611  Validation Accuracy: 0.515400
# Epoch 85, CIFAR-10 Batch 4:  Loss:     0.9563  Validation Accuracy: 0.514000
# Epoch 85, CIFAR-10 Batch 5:  Loss:     1.1674  Validation Accuracy: 0.522400
# Epoch 86, CIFAR-10 Batch 1:  Loss:     0.9789  Validation Accuracy: 0.523000
# Epoch 86, CIFAR-10 Batch 2:  Loss:     0.9566  Validation Accuracy: 0.512800
# Epoch 86, CIFAR-10 Batch 3:  Loss:     0.7504  Validation Accuracy: 0.505800
# Epoch 86, CIFAR-10 Batch 4:  Loss:     0.8232  Validation Accuracy: 0.492800
# Epoch 86, CIFAR-10 Batch 5:  Loss:     0.9622  Validation Accuracy: 0.516800
# Epoch 87, CIFAR-10 Batch 1:  Loss:     1.0951  Validation Accuracy: 0.511200
# Epoch 87, CIFAR-10 Batch 2:  Loss:     0.9180  Validation Accuracy: 0.524400
# Epoch 87, CIFAR-10 Batch 3:  Loss:     0.8298  Validation Accuracy: 0.509000
# Epoch 87, CIFAR-10 Batch 4:  Loss:     0.9659  Validation Accuracy: 0.510000
# Epoch 87, CIFAR-10 Batch 5:  Loss:     1.0496  Validation Accuracy: 0.507000
# Epoch 88, CIFAR-10 Batch 1:  Loss:     0.8660  Validation Accuracy: 0.510400
# Epoch 88, CIFAR-10 Batch 2:  Loss:     0.9408  Validation Accuracy: 0.535000
# Epoch 88, CIFAR-10 Batch 3:  Loss:     0.7457  Validation Accuracy: 0.514600
# Epoch 88, CIFAR-10 Batch 4:  Loss:     0.9631  Validation Accuracy: 0.525400
# Epoch 88, CIFAR-10 Batch 5:  Loss:     1.0395  Validation Accuracy: 0.502600
# Epoch 89, CIFAR-10 Batch 1:  Loss:     1.0166  Validation Accuracy: 0.501000
# Epoch 89, CIFAR-10 Batch 2:  Loss:     1.1067  Validation Accuracy: 0.532800
# Epoch 89, CIFAR-10 Batch 3:  Loss:     0.7976  Validation Accuracy: 0.526400
# Epoch 89, CIFAR-10 Batch 4:  Loss:     0.8960  Validation Accuracy: 0.530200
# Epoch 89, CIFAR-10 Batch 5:  Loss:     0.8353  Validation Accuracy: 0.527800
# Epoch 90, CIFAR-10 Batch 1:  Loss:     1.1335  Validation Accuracy: 0.536200
# Epoch 90, CIFAR-10 Batch 2:  Loss:     0.8803  Validation Accuracy: 0.517200
# Epoch 90, CIFAR-10 Batch 3:  Loss:     0.7830  Validation Accuracy: 0.484400
# Epoch 90, CIFAR-10 Batch 4:  Loss:     0.9151  Validation Accuracy: 0.521800
# Epoch 90, CIFAR-10 Batch 5:  Loss:     0.8799  Validation Accuracy: 0.526400
# Epoch 91, CIFAR-10 Batch 1:  Loss:     0.8259  Validation Accuracy: 0.502000
# Epoch 91, CIFAR-10 Batch 2:  Loss:     0.8719  Validation Accuracy: 0.518000
# Epoch 91, CIFAR-10 Batch 3:  Loss:     0.9422  Validation Accuracy: 0.505000
# Epoch 91, CIFAR-10 Batch 4:  Loss:     0.8686  Validation Accuracy: 0.519000
# Epoch 91, CIFAR-10 Batch 5:  Loss:     1.0241  Validation Accuracy: 0.512400
# Epoch 92, CIFAR-10 Batch 1:  Loss:     0.9456  Validation Accuracy: 0.527600
# Epoch 92, CIFAR-10 Batch 2:  Loss:     0.9770  Validation Accuracy: 0.538400
# Epoch 92, CIFAR-10 Batch 3:  Loss:     0.7217  Validation Accuracy: 0.523000
# Epoch 92, CIFAR-10 Batch 4:  Loss:     0.8119  Validation Accuracy: 0.522400
# Epoch 92, CIFAR-10 Batch 5:  Loss:     0.8395  Validation Accuracy: 0.511600
# Epoch 93, CIFAR-10 Batch 1:  Loss:     0.9221  Validation Accuracy: 0.520200
# Epoch 93, CIFAR-10 Batch 2:  Loss:     0.8564  Validation Accuracy: 0.522600
# Epoch 93, CIFAR-10 Batch 3:  Loss:     0.8179  Validation Accuracy: 0.526000
# Epoch 93, CIFAR-10 Batch 4:  Loss:     0.8367  Validation Accuracy: 0.517200
# Epoch 93, CIFAR-10 Batch 5:  Loss:     0.8885  Validation Accuracy: 0.514200
# Epoch 94, CIFAR-10 Batch 1:  Loss:     1.0682  Validation Accuracy: 0.527400
# Epoch 94, CIFAR-10 Batch 2:  Loss:     0.8572  Validation Accuracy: 0.531200
# Epoch 94, CIFAR-10 Batch 3:  Loss:     0.7614  Validation Accuracy: 0.494000
# Epoch 94, CIFAR-10 Batch 4:  Loss:     0.8824  Validation Accuracy: 0.527400
# Epoch 94, CIFAR-10 Batch 5:  Loss:     0.8316  Validation Accuracy: 0.503600
# Epoch 95, CIFAR-10 Batch 1:  Loss:     0.8210  Validation Accuracy: 0.523400
# Epoch 95, CIFAR-10 Batch 2:  Loss:     0.8332  Validation Accuracy: 0.528400
# Epoch 95, CIFAR-10 Batch 3:  Loss:     0.7235  Validation Accuracy: 0.524600
# Epoch 95, CIFAR-10 Batch 4:  Loss:     0.8392  Validation Accuracy: 0.522200
# Epoch 95, CIFAR-10 Batch 5:  Loss:     0.7983  Validation Accuracy: 0.516800
# Epoch 96, CIFAR-10 Batch 1:  Loss:     0.7861  Validation Accuracy: 0.515000
# Epoch 96, CIFAR-10 Batch 2:  Loss:     0.8968  Validation Accuracy: 0.536000
# Epoch 96, CIFAR-10 Batch 3:  Loss:     0.7114  Validation Accuracy: 0.511800
# Epoch 96, CIFAR-10 Batch 4:  Loss:     0.8706  Validation Accuracy: 0.519200
# Epoch 96, CIFAR-10 Batch 5:  Loss:     0.8206  Validation Accuracy: 0.513400
# Epoch 97, CIFAR-10 Batch 1:  Loss:     0.8790  Validation Accuracy: 0.534000
# Epoch 97, CIFAR-10 Batch 2:  Loss:     0.8926  Validation Accuracy: 0.493800
# Epoch 97, CIFAR-10 Batch 3:  Loss:     0.7709  Validation Accuracy: 0.506600
# Epoch 97, CIFAR-10 Batch 4:  Loss:     0.7727  Validation Accuracy: 0.521800
# Epoch 97, CIFAR-10 Batch 5:  Loss:     0.9396  Validation Accuracy: 0.514200
# Epoch 98, CIFAR-10 Batch 1:  Loss:     0.9650  Validation Accuracy: 0.533800
# Epoch 98, CIFAR-10 Batch 2:  Loss:     0.8161  Validation Accuracy: 0.518800
# Epoch 98, CIFAR-10 Batch 3:  Loss:     0.7131  Validation Accuracy: 0.512000
# Epoch 98, CIFAR-10 Batch 4:  Loss:     0.9327  Validation Accuracy: 0.527200
# Epoch 98, CIFAR-10 Batch 5:  Loss:     0.7960  Validation Accuracy: 0.509200
# Epoch 99, CIFAR-10 Batch 1:  Loss:     0.8987  Validation Accuracy: 0.524600
# Epoch 99, CIFAR-10 Batch 2:  Loss:     0.8454  Validation Accuracy: 0.530000
# Epoch 99, CIFAR-10 Batch 3:  Loss:     0.7046  Validation Accuracy: 0.528600
# Epoch 99, CIFAR-10 Batch 4:  Loss:     0.8069  Validation Accuracy: 0.498400
# Epoch 99, CIFAR-10 Batch 5:  Loss:     0.7558  Validation Accuracy: 0.528600
# Epoch 100, CIFAR-10 Batch 1:  Loss:     0.8132  Validation Accuracy: 0.534400
# Epoch 100, CIFAR-10 Batch 2:  Loss:     0.9026  Validation Accuracy: 0.534200
# Epoch 100, CIFAR-10 Batch 3:  Loss:     0.7793  Validation Accuracy: 0.487800
# Epoch 100, CIFAR-10 Batch 4:  Loss:     0.7725  Validation Accuracy: 0.529400
# Epoch 100, CIFAR-10 Batch 5:  Loss:     0.9014  Validation Accuracy: 0.515600

# %% [markdown]
# # Checkpoint
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_test.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for test_feature_batch, test_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: test_feature_batch, loaded_y: test_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# INFO:tensorflow:Restoring parameters from ./image_classification
# Testing Accuracy: 0.52255859375

# %% [markdown]
# ## Why 50-80% Accuracy?
# You might be wondering why you can't get an accuracy any higher. First things first, 50% isn't bad for a simple CNN.  Pure guessing would get you 10% accuracy. However, you might notice people are getting scores [well above 80%](http://rodrigob.github.io/are_we_there_yet/build/classification_datasets_results.html#43494641522d3130).  That's because we haven't taught you all there is to know about neural networks. We still need to cover a few more techniques.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook.  Save the notebook file as "dlnd_image_classification.ipynb" and save it as a HTML file under "File" -> "Download as".  Include the "helper.py" and "problem_unittests.py" files in your submission.
